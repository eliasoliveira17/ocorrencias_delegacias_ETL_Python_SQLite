# %%
import pandas as pd
from datetime import datetime
from pathlib import Path
import sqlite3 as sql

# %% [markdown]
# # CRIANDO O BANCO DE DADOS

# %%
endereco = Path('C:\\Users\\elias\\Downloads\\Engenharia de Dados com Python\\Bancos de Dados\\')

BDODS = endereco / "pascoaODS.db"
BDDW = endereco / "pascoaDW.db"

if endereco.exists():
    print("Endereço existe!")
    if (BDODS.exists() and BDDW.exists()):
        print("Bancos de dados já existem!")
    else:
        BDODS.touch()
        BDDW.touch()
        print("Bancos de dados acabaram de ser criados!")
else:
    print("Endereço não existe. Favor, verificar!")
# Out:
# Endereço existe!
# Bancos de dados já existem!

# %% [markdown]
# # CARGA DOS DADOS DE DELEGACIA DE POLÍCIA

# %%
dtCarga = datetime.today().strftime('%d/%m/%Y %H:%M')
dtCarga
# Out:
# '08/09/2022 22:09'

# %%
# pasta com csv
localCSV = 'C:\\Users\\elias\\Downloads\\Engenharia de Dados com Python\\Arquivos CSV\\'

# carga dos dados de cadastro das delegacias
tbLogDP = pd.DataFrame(pd.read_csv(localCSV + 'DP.csv'))

# adicionar data e hora
tbLogDP['dtCarga'] = dtCarga
# selecionar coluna COD_CP como índice
# tbLogDP = tbLogDP.set_index('COD_DP')

# %%
tbLogDP
# Out:
#      COD_DP                          NM_DP  \
# 0         1           001ª DP - Praça Mauá
# 1         4   004ª DP - Praça da República
# 2         5            005ª DP - Mem de Sá
# 3         6          006ª DP - Cidade Nova
# 4         7         007ª DP - Santa Teresa
# ..      ...                            ...
# 132     159  159ª DP - Cachoeira de Macacu
# 133     165          165ª DP - Mangaratiba
# 134     166       166ª DP - Angra dos Reis
# 135     167               167ª DP - Paraty
# 136     168            168ª DP - Rio Claro
#
#                                               Endereço           dtCarga
# 0    Atendendo provisoriamente na sede da 4ª DP - P...  08/09/2022 22:09
# 1    Av. Presidente Vargas, 1100 - Centro, Rio de J...  08/09/2022 22:09
# 2    Avenida Gomes Freire, 320 - Centro, Rio de Jan...  08/09/2022 22:09
# 3    Rua Professor Clementino Fraga, 77 - Centro, R...  08/09/2022 22:09
# 4    Rua Francisco de Castro, 5 - Santa Teresa, Rio...  08/09/2022 22:09
# ..                                                 ...               ...
# 132  Avenida Lord Baden Powel, 93 - Centro, Cachoei...  08/09/2022 22:09
# 133  Estrada São João Marcos, s/n - Praia do Saco, ...  08/09/2022 22:09
# 134  Rua Doutor Coutinho, 6 - Centro, Angra dos Rei...  08/09/2022 22:09
# 135  Rua Roberto da Silveira , s/n - Vila Colonial,...  08/09/2022 22:09
# 136  Praça Fagundes Vahera, 62, Rio Claro, Rio de J...  08/09/2022 22:09
#
# [137 rows x 4 columns]

# %%
# carga dos dados de responsáveis das delegacias
tbLogRespDP = pd.DataFrame(pd.read_csv(localCSV + 'ResponsavelDP.csv'))

# adicionar data da carga
tbLogRespDP['dtCarga'] = dtCarga
# selecionar coluna COD_CP como índice
# tbLogRespDP = tbLogRespDP.set_index('COD_DP')

# %%
tbLogRespDP
# Out:
#      COD_DP                                        Responsavel  \
# 0         1         Delegado de Polícia José Luiz Silva Duarte
# 1         4       Delegada de Polícia Patricia de Paiva Aguiar
# 2         5        Delegado de Polícia Bruno Gilaberte Freitas
# 3         6      Delegado de Polícia Fabio Luiz Da Silva Souza
# 4         7  Delegado de Polícia Carlos Alberto Meirelles D...
# ..      ...                                                ...
# 132     159           Delegado de Polícia Clovis Souza Moreira
# 133     165         Delegado de Polícia Anderson Ribeiro Pinto
# 134     166        Delegado de Polícia Vilson de Almeida Silva
# 135     167      Delegado de Polícia Marcelo dos Santos Haddad
# 136     168        Delegado de Polícia Francisco Benitez Lopes
#
#               dtCarga
# 0    08/09/2022 22:09
# 1    08/09/2022 22:09
# 2    08/09/2022 22:09
# 3    08/09/2022 22:09
# 4    08/09/2022 22:09
# ..                ...
# 132  08/09/2022 22:09
# 133  08/09/2022 22:09
# 134  08/09/2022 22:09
# 135  08/09/2022 22:09
# 136  08/09/2022 22:09
#
# [137 rows x 3 columns]

# %% [markdown]
# # CONEXÃO E CARGA AO BANCO DE DADOS

# %%
# estabelece conexão ao banco de dados BDODS
conexaoBDODS = sql.connect(BDODS)

# definição da manipulação de dados em SQL
SQL_ODS = conexaoBDODS.cursor()

# inserindo registros na tabela tbLogDP
print('Iniciando a inserção de dados na tabela tbLogDP')

# 
SQL_ODS.executemany('''INSERT INTO tbLogDP (codDP,nmDP,endereco,dtCarga) VALUES (?,?,?,?)''',tbLogDP.values.tolist())

# confirma a transação
conexaoBDODS.commit()

print('Carga de', len(tbLogDP), 'registros em tbLogDP finalizada ')

# inserindo registros na tabela tbLogRespDP
print('Iniciando a inserção de dados na tabela tbLogRespDP')

# 
SQL_ODS.executemany('''INSERT INTO tbLogRespDP (codDP,nmResponsavel,dtCarga) VALUES (?,?,?)''',tbLogRespDP.values.tolist())

# confirma a transação
conexaoBDODS.commit()

print('Carga de', len(tbLogRespDP), 'registros em tbLogRespDP finalizada ')
# Out:
# Iniciando a inserção de dados na tabela tbLogDP
# Carga de 137 registros em tbLogDP finalizada
# Iniciando a inserção de dados na tabela tbLogRespDP
# Carga de 137 registros em tbLogRespDP finalizada

# %%
# inserindo a query

qry_sql = '''
SELECT
    codDP,
    nmDP,
    endereco,
    nmResponsavel
FROM (
SELECT
    a.codDP,
    a.nmDP,
    a.endereco,
    b.nmResponsavel,
    max(a.dtCarga)
FROM tbLogDP a
JOIN tbLogRespDP b
on a.codDP = b.codDP
GROUP BY
    a.codDP,
    a.nmDP,
    a.endereco,
    b.nmResponsavel
    )
'''

# leitura de dDP
dDP = pd.read_sql(qry_sql, conexaoBDODS)

# confirma a transação
conexaoBDODS.commit()

# encerra conexão com o banco de dados BDODS
conexaoBDODS.close()

dDP
# Out:
#      codDP                           nmDP  \
# 0        1           001ª DP - Praça Mauá
# 1        4   004ª DP - Praça da República
# 2        5            005ª DP - Mem de Sá
# 3        6          006ª DP - Cidade Nova
# 4        7         007ª DP - Santa Teresa
# ..     ...                            ...
# 132    159  159ª DP - Cachoeira de Macacu
# 133    165          165ª DP - Mangaratiba
# 134    166       166ª DP - Angra dos Reis
# 135    167               167ª DP - Paraty
# 136    168            168ª DP - Rio Claro
#
#                                               endereco  \
# 0    Atendendo provisoriamente na sede da 4ª DP - P...
# 1    Av. Presidente Vargas, 1100 - Centro, Rio de J...
# 2    Avenida Gomes Freire, 320 - Centro, Rio de Jan...
# 3    Rua Professor Clementino Fraga, 77 - Centro, R...
# 4    Rua Francisco de Castro, 5 - Santa Teresa, Rio...
# ..                                                 ...
# 132  Avenida Lord Baden Powel, 93 - Centro, Cachoei...
# 133  Estrada São João Marcos, s/n - Praia do Saco, ...
# 134  Rua Doutor Coutinho, 6 - Centro, Angra dos Rei...
# 135  Rua Roberto da Silveira , s/n - Vila Colonial,...
# 136  Praça Fagundes Vahera, 62, Rio Claro, Rio de J...
#
#                                          nmResponsavel
# 0           Delegado de Polícia José Luiz Silva Duarte
# 1         Delegada de Polícia Patricia de Paiva Aguiar
# 2          Delegado de Polícia Bruno Gilaberte Freitas
# 3        Delegado de Polícia Fabio Luiz Da Silva Souza
# 4    Delegado de Polícia Carlos Alberto Meirelles D...
# ..                                                 ...
# 132           Delegado de Polícia Clovis Souza Moreira
# 133         Delegado de Polícia Anderson Ribeiro Pinto
# 134        Delegado de Polícia Vilson de Almeida Silva
# 135      Delegado de Polícia Marcelo dos Santos Haddad
# 136        Delegado de Polícia Francisco Benitez Lopes
#
# [137 rows x 4 columns]

# %% [markdown]
# # CONECTANDO AO DW E DELETANDO DADOS ANTIGOS E REINICIANDO O AUTOINCRIMENTAL DA CHAVE

# %%
# estabele conexão com BDDW
conexaoBDDW = sql.connect(BDDW)
# definição da manipulação de dados em SQL
SQL_DW = conexaoBDDW.cursor()

# 
SQL_DW.execute('DELETE FROM dDP')
               
# confirmar transação
conexaoBDDW.commit()
               
# reiniciar o autoincremento do índice
SQL_DW.execute("UPDATE sqlite_sequence SET seq=0 where name='dDP'")

# confirmar transação
conexaoBDDW.commit()

# %% [markdown]
# # INSERINDO DADOS NA DIMENSÃO DP NO DW

# %%
# inserindo registros na tabela dDP
print('Iniciando a inserção de dados na tabela dDP')

# OBS: não há necessidade de informar a coluna de índice (autoincrimental)
SQL_DW.executemany('''INSERT INTO dDP (codDP,nmDP,endereco,nmResponsavel) VALUES (?,?,?,?)''',dDP.values.tolist())

# confirma a transação
conexaoBDDW.commit()

print('Carga de', len(dDP), 'registros em dDP finalizada ')
# Out:
# Iniciando a inserção de dados na tabela dDP
# Carga de 137 registros em dDP finalizada

# %% [markdown]
# # validar a carga de dDP atravpes de select

# %%
pd.read_sql('SELECT * FROM dDP', conexaoBDDW)
# Out:
#      idDP  codDP                           nmDP  \
# 0       1      1           001ª DP - Praça Mauá
# 1       2      4   004ª DP - Praça da República
# 2       3      5            005ª DP - Mem de Sá
# 3       4      6          006ª DP - Cidade Nova
# 4       5      7         007ª DP - Santa Teresa
# ..    ...    ...                            ...
# 132   133    159  159ª DP - Cachoeira de Macacu
# 133   134    165          165ª DP - Mangaratiba
# 134   135    166       166ª DP - Angra dos Reis
# 135   136    167               167ª DP - Paraty
# 136   137    168            168ª DP - Rio Claro
#
#                                               endereco  \
# 0    Atendendo provisoriamente na sede da 4ª DP - P...
# 1    Av. Presidente Vargas, 1100 - Centro, Rio de J...
# 2    Avenida Gomes Freire, 320 - Centro, Rio de Jan...
# 3    Rua Professor Clementino Fraga, 77 - Centro, R...
# 4    Rua Francisco de Castro, 5 - Santa Teresa, Rio...
# ..                                                 ...
# 132  Avenida Lord Baden Powel, 93 - Centro, Cachoei...
# 133  Estrada São João Marcos, s/n - Praia do Saco, ...
# 134  Rua Doutor Coutinho, 6 - Centro, Angra dos Rei...
# 135  Rua Roberto da Silveira , s/n - Vila Colonial,...
# 136  Praça Fagundes Vahera, 62, Rio Claro, Rio de J...
#
#                                          nmResponsavel
# 0           Delegado de Polícia José Luiz Silva Duarte
# 1         Delegada de Polícia Patricia de Paiva Aguiar
# 2          Delegado de Polícia Bruno Gilaberte Freitas
# 3        Delegado de Polícia Fabio Luiz Da Silva Souza
# 4    Delegado de Polícia Carlos Alberto Meirelles D...
# ..                                                 ...
# 132           Delegado de Polícia Clovis Souza Moreira
# 133         Delegado de Polícia Anderson Ribeiro Pinto
# 134        Delegado de Polícia Vilson de Almeida Silva
# 135      Delegado de Polícia Marcelo dos Santos Haddad
# 136        Delegado de Polícia Francisco Benitez Lopes
#
# [137 rows x 5 columns]

# %% [markdown]
# # FECHANDO A CONEXÃO COM DW

# %%
conexaoBDDW.close()
